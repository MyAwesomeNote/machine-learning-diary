# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as seabornInstance
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.linear_model import LinearRegression

# %matplotlib inline

# %%
dataset = pd.read_csv('../data/weather.csv')

# %%
dataset.plot(
    x="MinTemp",
    y="MaxTemp",
    style="o"
)

plt.title("MinTemp vs MaxTemp")
plt.xlabel("MinTemp")
plt.ylabel("MaxTemp")
plt.show()

# %%
x = dataset["MinTemp"].values.reshape(-1, 1)
y = dataset["MaxTemp"].values.reshape(-1, 1)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test)
df = pd.DataFrame({"Actual": y_test.flatten(), "Predicted": y_pred.flatten()})

df  # jupyter shows the return value of the last line
# Out:
#     Actual  Predicted
# 0     31.3  25.383144
# 1     17.3  26.688990
# 2     31.2  22.853068
# 3     16.3  15.017993
# 4     20.7  15.344455
# ..     ...        ...
# 69    12.2  14.120224
# 70    29.4  26.852221
# 71    30.2  24.158914
# 72    16.7  14.691532
# 73    21.8  17.466454
#
# [74 rows x 2 columns]

# %%
plt.scatter(x_test, y_test, color="blue")
plt.plot(x_test, y_pred, color="red", linewidth=3)

plt.show()

# %% [markdown]
# $$MSE = \frac{1}{n} \sum_{i=1}^{n} (y_i - \hat{y_i})^2$$
# $$RMSE = \sqrt{\frac{1}{n} \sum_{i=1}^{n} (y_i - \hat{y_i})^2}$$

# %%
print("평균제곱법:", metrics.mean_squared_error(y_test, y_pred))
print("루트평균제곱법:", np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# 평균제곱법: 21.45884617135797
# 루트평균제곱법: 4.632369390642111
